# %%
import pandas as pd

# %%
pd.read_csv(./ml-latest-small.zip/)

# %%
movies_id=pd.read_csv(r"C:\New folder (4)\ml-latest-small\ml-latest-small\movies.csv")

# %%
movies_id
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
links=pd.read_csv("./ml-latest-small/ml-latest-small/tags.csv")

# %%
links
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
data= links.merge(movies_id,how= 'left',on=movies_id)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 data= links.merge(movies_id,how= 'left',on=movies_id)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10083, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10064 @Substitution("")
#   10065 @Appender(_merge_doc, indents=2)
#   10066 def merge(
#    (...)
#   10079     validate: str | None = None,
#   10080 ) -> DataFrame:
#   10081     from pandas.core.reshape.merge import merge
# > 10083     return merge(
#   10084         self,
#   10085         right,
#   10086         how=how,
#   10087         on=on,
#   10088         left_on=left_on,
#   10089         right_on=right_on,
#   10090         left_index=left_index,
#   10091         right_index=right_index,
# ...
