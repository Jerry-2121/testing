# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv("Sales Transactions-2017.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 df1 = pd.read_csv("Sales Transactions-2017.csv")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# ...

# %%
df2 = pd.read_csv("Sales Transactions-2018.csv")

# %%
df3 = pd.read_csv("Sales Transactions-2019.csv")

# %%
final = pd.read_csv("Sales-Transactions-Edited.csv")

# %%
final.isna().sum()

# %%
final.info()

# %%
final

# %%
df1

# %% [markdown]
# ### Concating

# %%
merged = pd.concat([df1,df2,df3])

# %%
merged

# %%
merged.drop(labels=["Disc","Voucher Amount"],axis=1,inplace=True)

# %%
merged.isna().sum()

# %%
merged.dropna(subset="Rate",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 merged.dropna(subset="Rate",inplace=True)
#
# NameError: name 'merged' is not defined

# %%
merged.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 merged.isna().sum()
#
# NameError: name 'merged' is not defined

# %%
merged.isna().sum()
# Out:
# Date       34
# Voucher     0
# Party      34
# Product    34
# Qty         0
# Rate        0
# Gross       0
# dtype: int64

# %%
merged.isnull().sum()
# Out:
# Date       34
# Voucher     0
# Party      34
# Product    34
# Qty         0
# Rate        0
# Gross       0
# dtype: int64

# %%
merged[merged["Date"].isna()]
# Out:
#       Date  Voucher Party Product           Qty           Rate           Gross
# 4286   NaN  Total     NaN     NaN    725,098.20     892,995.90   10,156,375.86
# 9440   NaN  Total     NaN     NaN    864,048.00     842,990.34   11,738,640.00
# 13637  NaN  Total     NaN     NaN    742,449.00     639,799.63    9,994,892.00
# 17195  NaN  Total     NaN     NaN    569,166.00     684,525.17    9,196,270.50
# 21653  NaN  Total     NaN     NaN    800,911.60     916,383.98   11,487,277.00
# 25642  NaN  Total     NaN     NaN    616,175.60     654,104.12    9,814,351.46
# 29365  NaN  Total     NaN     NaN    638,342.70     621,104.41    9,496,760.91
# 33121  NaN  Total     NaN     NaN    551,198.00     643,446.58    9,132,584.78
# 37214  NaN  Total     NaN     NaN    538,900.90     728,887.38    9,390,510.25
# 40415  NaN  Total     NaN     NaN    458,230.80     554,312.00    7,844,514.06
# 43289  NaN  Total     NaN     NaN    480,806.30     461,266.00    7,572,732.76
# ...

# %%
merged.dropna(subset="Date",inplace=True) # This is the line to Drop Na values in the date column

# %%
merged.isna().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       0
# Gross      0
# dtype: int64

# %%
merged.reset_index(drop=True,inplace=True)

# %%
merged
# Out:
#              Date   Voucher               Party              Product  Qty  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...       ...                 ...                  ...  ...
# 98609  10/10/2019  Sal:4935           K.SRIHARI         16*20(100-W)  140
# 98610  10/10/2019  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 98611  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 98612  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK  800
# 98613  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK  400
#
#            Rate      Gross
# 0      1,690.00   3,380.00
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98614 entries, 0 to 98613
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     98614 non-null  object
#  1   Voucher  98614 non-null  object
#  2   Party    98614 non-null  object
#  3   Product  98614 non-null  object
#  4   Qty      98614 non-null  object
#  5   Rate     98614 non-null  object
#  6   Gross    98614 non-null  object
# dtypes: object(7)
# memory usage: 5.3+ MB

# %%
merged["Qty"]
# Out:
# 0          2
# 1          6
# 2        500
# 3          6
# 4          5
#         ...
# 98609    140
# 98610    600
# 98611    320
# 98612    800
# 98613    400
# Name: Qty, Length: 98614, dtype: object

# %%
pd.to_numeric(merged["Qty"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 pd.to_numeric(merged["Qty"])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
merged[["Qty"]].head(10)
# Out:
#    Qty
# 0    2
# 1    6
# 2  500
# 3    6
# 4    5
# 5    1
# 6  100
# 7  100
# 8
# 9

# %%
merged.head(10)
# Out:
#        Date  Voucher                Party             Product  Qty      Rate  \
# 0  1/4/2017    Sal:1     SOLANKI PLASTICS       DONA-VAI-9100    2  1,690.00
# 1  1/4/2017    Sal:1     SOLANKI PLASTICS     LITE FOAM(1200)    6  1,620.00
# 2  1/4/2017    Sal:2   SARNESWARA TRADERS   VISHNU CHOTA WINE  500        23
# 3  1/4/2017    Sal:2   SARNESWARA TRADERS     LITE FOAM(1200)    6  1,620.00
# 4  1/4/2017    Sal:2   SARNESWARA TRADERS       DONA-VAI-9100    5  1,690.00
# 5  1/4/2017    Sal:2   SARNESWARA TRADERS  CLASSIC ENJOY(750)    1  1,320.00
# 6  1/4/2017  Sal:898                 Lock        Vishnu 250ml  100        30
# 7  1/4/2017  Sal:898                 Lock     BLACK DOG-350ML  100        26
# 8                     khader vali late en
# 9                                     try
#
#        Gross
# 0   3,380.00
# 1   9,720.00
# 2  11,500.00
# 3   9,720.00
# 4   8,450.00
# 5   1,320.00
# 6   3,000.00
# 7   2,600.00
# 8
# 9

# %%
merged=merged[merged["Date"] != " "]

# %%
merged.reset_index(drop=True)
# Out:
#              Date   Voucher               Party              Product  Qty  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...       ...                 ...                  ...  ...
# 95556  10/10/2019  Sal:4935           K.SRIHARI         16*20(100-W)  140
# 95557  10/10/2019  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 95558  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 95559  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK  800
# 95560  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK  400
#
#            Rate      Gross
# 0      1,690.00   3,380.00
# ...

# %%
pd.to_numeric(merged["Qty"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,000.00"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 pd.to_numeric(merged["Qty"])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
merged.reset_index(drop=True,inplace=True)

# %%
merged.head(30)
# Out:
#         Date   Voucher                Party              Product       Qty  \
# 0   1/4/2017     Sal:1     SOLANKI PLASTICS        DONA-VAI-9100         2
# 1   1/4/2017     Sal:1     SOLANKI PLASTICS      LITE FOAM(1200)         6
# 2   1/4/2017     Sal:2   SARNESWARA TRADERS    VISHNU CHOTA WINE       500
# 3   1/4/2017     Sal:2   SARNESWARA TRADERS      LITE FOAM(1200)         6
# 4   1/4/2017     Sal:2   SARNESWARA TRADERS        DONA-VAI-9100         5
# 5   1/4/2017     Sal:2   SARNESWARA TRADERS   CLASSIC ENJOY(750)         1
# 6   1/4/2017   Sal:898                 Lock         Vishnu 250ml       100
# 7   1/4/2017   Sal:898                 Lock      BLACK DOG-350ML       100
# 8   1/4/2017  Sal:2497  VAMSI KRISHNA FANCY          Loose Items         1
# 9   1/4/2017  Sal:9263  VAMSI KRISHNA FANCY          Loose Items         1
# 10  1/4/2017  Sal:9545                  Vkp          Loose Items         1
# ...

# %%
merged["Qty"] = merged["Qty"].replace(",","",regex=True)
# Out:
# C:\Users\Chetan\AppData\Local\Temp\ipykernel_16480\1673436572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged["Qty"] = merged["Qty"].replace(",","",regex=True)

# %%
merged.head(30)
# Out:
#         Date   Voucher                Party              Product      Qty  \
# 0   1/4/2017     Sal:1     SOLANKI PLASTICS        DONA-VAI-9100        2
# 1   1/4/2017     Sal:1     SOLANKI PLASTICS      LITE FOAM(1200)        6
# 2   1/4/2017     Sal:2   SARNESWARA TRADERS    VISHNU CHOTA WINE      500
# 3   1/4/2017     Sal:2   SARNESWARA TRADERS      LITE FOAM(1200)        6
# 4   1/4/2017     Sal:2   SARNESWARA TRADERS        DONA-VAI-9100        5
# 5   1/4/2017     Sal:2   SARNESWARA TRADERS   CLASSIC ENJOY(750)        1
# 6   1/4/2017   Sal:898                 Lock         Vishnu 250ml      100
# 7   1/4/2017   Sal:898                 Lock      BLACK DOG-350ML      100
# 8   1/4/2017  Sal:2497  VAMSI KRISHNA FANCY          Loose Items        1
# 9   1/4/2017  Sal:9263  VAMSI KRISHNA FANCY          Loose Items        1
# 10  1/4/2017  Sal:9545                  Vkp          Loose Items        1
# 11  2/4/2017    Sal:16                  KPR      LITE FOAM(1200)        1
# ...

# %%
pd.to_numeric(merged["Qty"])
# Out:
# 0          2.0
# 1          6.0
# 2        500.0
# 3          6.0
# 4          5.0
#          ...
# 95556    140.0
# 95557    600.0
# 95558    320.0
# 95559    800.0
# 95560    400.0
# Name: Qty, Length: 95561, dtype: float64

# %%
merged["Qty"] =pd.to_numeric(merged["Qty"])


#df["2nd"] = pd.to_numeric(df["2nd"])
# Out:
# C:\Users\Chetan\AppData\Local\Temp\ipykernel_16480\4118075481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged["Qty"] =pd.to_numeric(merged["Qty"])

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95561 entries, 0 to 95560
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     95561 non-null  object
#  1   Voucher  95561 non-null  object
#  2   Party    95561 non-null  object
#  3   Product  95561 non-null  object
#  4   Qty      95561 non-null  float64
#  5   Rate     95561 non-null  object
#  6   Gross    95561 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 5.1+ MB

# %%
merged
# Out:
#              Date   Voucher               Party              Product    Qty  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2.0
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6.0
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500.0
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6.0
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5.0
# ...           ...       ...                 ...                  ...    ...
# 95556  10/10/2019  Sal:4935           K.SRIHARI         16*20(100-W)  140.0
# 95557  10/10/2019  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600.0
# 95558  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320.0
# 95559  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK  800.0
# 95560  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK  400.0
#
#            Rate      Gross
# 0      1,690.00   3,380.00
# ...

# %%
merged["Rate"] = pd.to_numeric(merged["Rate"].replace(",","",regex=True))
# Out:
# C:\Users\Chetan\AppData\Local\Temp\ipykernel_16480\3280663986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged["Rate"] = pd.to_numeric(merged["Rate"].replace(",","",regex=True))

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95561 entries, 0 to 95560
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     95561 non-null  object
#  1   Voucher  95561 non-null  object
#  2   Party    95561 non-null  object
#  3   Product  95561 non-null  object
#  4   Qty      95561 non-null  float64
#  5   Rate     95561 non-null  float64
#  6   Gross    95561 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 5.1+ MB

# %%
merged["Gross"] = pd.to_numeric(merged["Gross"].replace(",","",regex=True))
# Out:
# C:\Users\Chetan\AppData\Local\Temp\ipykernel_16480\1597697716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged["Gross"] = pd.to_numeric(merged["Gross"].replace(",","",regex=True))

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95561 entries, 0 to 95560
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     95561 non-null  object
#  1   Voucher  95561 non-null  object
#  2   Party    95561 non-null  object
#  3   Product  95561 non-null  object
#  4   Qty      95561 non-null  float64
#  5   Rate     95561 non-null  float64
#  6   Gross    95561 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 5.1+ MB

# %%
merged["Date"]= pd.to_datetime(merged["Date"])
# Out:
# C:\Users\Chetan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Chetan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Chetan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95561 entries, 0 to 95560
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     95561 non-null  datetime64[ns]
#  1   Voucher  95561 non-null  object
#  2   Party    95561 non-null  object
#  3   Product  95561 non-null  object
#  4   Qty      95561 non-null  float64
#  5   Rate     95561 non-null  float64
#  6   Gross    95561 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 5.1+ MB

# %%
merged[(merged["Voucher"] == "Sal:1") & (merged["Date"] == "2017-01-04")]["Gross"].sum()
# Out:
# 13100.0

# %%
merged
# Out:
#             Date   Voucher               Party              Product    Qty  \
# 0     2017-01-04     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2.0
# 1     2017-01-04     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6.0
# 2     2017-01-04     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500.0
# 3     2017-01-04     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6.0
# 4     2017-01-04     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5.0
# ...          ...       ...                 ...                  ...    ...
# 95556 2019-10-10  Sal:4935           K.SRIHARI         16*20(100-W)  140.0
# 95557 2019-10-10  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600.0
# 95558 2019-10-10  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320.0
# 95559 2019-10-10  Sal:4935           K.SRIHARI             10*12 RK  800.0
# 95560 2019-10-10  Sal:4935           K.SRIHARI       13*16 WHITE RK  400.0
#
#          Rate    Gross
# 0      1690.0   3380.0
# ...

# %%
df1
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
merged.to_csv("Processed.csv",index=False)

# %%
data = pd.read_csv("Processed.csv")

# %%
len(data[data["Party"] == "SOLANKI PLASTICS"]["Voucher"].unique())
# Out:
# 62

# %%
data[data["Party"] == "SOLANKI PLASTICS"][["Gross","Qty"]].sum()
# Out:
# Gross    863613.0
# Qty        2973.0
# dtype: float64

# %%
data
# Out:
#              Date   Voucher               Party              Product    Qty  \
# 0      2017-01-04     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2.0
# 1      2017-01-04     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6.0
# 2      2017-01-04     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500.0
# 3      2017-01-04     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6.0
# 4      2017-01-04     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5.0
# ...           ...       ...                 ...                  ...    ...
# 95556  2019-10-10  Sal:4935           K.SRIHARI         16*20(100-W)  140.0
# 95557  2019-10-10  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600.0
# 95558  2019-10-10  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320.0
# 95559  2019-10-10  Sal:4935           K.SRIHARI             10*12 RK  800.0
# 95560  2019-10-10  Sal:4935           K.SRIHARI       13*16 WHITE RK  400.0
#
#          Rate    Gross
# 0      1690.0   3380.0
# ...
